# %%
import string
from collections import deque
# Read input data
with open("input.txt", "r") as f:
    arr = f.readlines()

# Create dictionary for values
letters = string.ascii_lowercase + string.ascii_uppercase
dict = {letter: index for index, letter in enumerate(letters, 1)}    

print(arr[0:3])
# Out:
# ['rNZNWvMZZmDDmwqNdZrWTqhJMhhgzggBhzBJBchQzzJJ\n', 'pHlSVbVbFHgHBzzhQHqg\n', 'nVsqGpbbtDtTNmrmfZ\n']

# %%
# Convert to pairs, split down middle
pairs = []
for d in range(0,len(arr)):
    key = int(len(arr[1])/2)
    pairs.append(([ [arr[1][0:key]], [arr[1][key:].strip()] ]))

print(pairs[1])
print(pairs[1][1][0][1:3])
print(len(pairs[1][0][0]))
    
sum = 0
# Find duplicate

                
for i in range(len(pairs)): # For all pairs
    for j in range(len(pairs[i][0][0])): # For all letters in one segment
        for k in range(len(pairs[i][1][0])): # Iterate over every letter in other segment
            if pairs[i][0][0][j] == pairs[i][1][0][k]:
                dupe = pairs[i][0][0][j]
                print(dupe)
                sum += dict[dupe]
                break
                
print(sum)
# Out:
# [['pHlSVbVbFH'], ['gHBzzhQHqg']]
# HB
# 10
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# H
# ...

# %%
print(pairs[i][0])
# Out:
# [['pHlSVbVbFH'], ['gHBzzhQHqg']]
